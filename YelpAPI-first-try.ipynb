# %%
import pandas as pd
import numpy as np
import json
with open('/Users/Lonnie/.secret/yelp_api.json') as f: #change the path to match YOUR path!!
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
from yelpapi import YelpAPI
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
help(yelp_api.search_query)
# Out:
# Help on method search_query in module yelpapi.yelpapi:
#
# search_query(**kwargs) method of yelpapi.yelpapi.YelpAPI instance
#     Query the Yelp Search API.
#
#     documentation: https://www.yelp.com/developers/documentation/v3/business_search
#
#     required parameters:
#         * one of either:
#             * location - text specifying a location to search for
#             * latitude and longitude

# %%
search_results = yelp_api.search_query(location='NY, NY', term='Pizza')

print(type(search_results))
search_results.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
search_results['total']
# Out:
# 15600

# %%
biz = pd.DataFrame(search_results['businesses'])
biz.head(2)
# Out:
#                        id                           alias  \
# 0  zj8Lq1T8KIC5zwFief15jg  prince-street-pizza-new-york-2
# 1  ysqgdbSrezXgVwER2kQWKA             julianas-brooklyn-3
#
#                   name                                          image_url  \
# 0  Prince Street Pizza  https://s3-media2.fl.yelpcdn.com/bphoto/I4gm7i...
# 1            Juliana's  https://s3-media2.fl.yelpcdn.com/bphoto/NVoLFl...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/prince-street-pizza-n...          4747
# 1      False  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2602
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 1             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
#
#                                          coordinates        transactions  \
# ...

# %%
search_results = yelp_api.search_query(location='NY, NY', term='Pizza', offset = 30)

# %%
biz20 = pd.DataFrame(search_results['businesses'])
biz20.head(2)
# Out:
#                        id                         alias               name  \
# 0  bB5b8cj0yWNJvmmLiQeWGA  piccolo-trattoria-new-york-2  Piccolo Trattoria
# 1  2xQmBB6w-W6lxiex80fA9A    luigis-pizzeria-brooklyn-4   Luigi's Pizzeria
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/00Umc7...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/j8wXRU...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/piccolo-trattoria-new...           116
# 1  https://www.yelp.com/biz/luigis-pizzeria-brook...           281
#
#                                categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}]     3.0
# 1  [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 40.7591676767848, 'longitude': -7...  [delivery, pickup]
# ...

# %%
len(search_results['businesses'])
# Out:
# 20

# %%
## concatenate the previous results and new results. 
businesses = pd.concat([biz, biz20],
                      ignore_index=True)
display(businesses.head(3), businesses.tail(3))
# Out:
#                        id                           alias  \
# 0  zj8Lq1T8KIC5zwFief15jg  prince-street-pizza-new-york-2
# 1  ysqgdbSrezXgVwER2kQWKA             julianas-brooklyn-3
# 2  WG639VkTjmK5dzydd1BBJA             rubirosa-new-york-2
#
#                   name                                          image_url  \
# 0  Prince Street Pizza  https://s3-media2.fl.yelpcdn.com/bphoto/I4gm7i...
# 1            Juliana's  https://s3-media2.fl.yelpcdn.com/bphoto/NVoLFl...
# 2             Rubirosa  https://s3-media4.fl.yelpcdn.com/bphoto/LuSzR8...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/prince-street-pizza-n...          4747
# 1      False  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2602
# 2      False  https://www.yelp.com/biz/rubirosa-new-york-2?a...          2904
#
#                                           categories  rating  \
# ...
